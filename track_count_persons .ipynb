# %% [markdown]
# # 環境設置

# %%
# !python --version
# Out:
# Python 3.10.13

# %%
import ultralytics
import torch

print(ultralytics.__version__)
print(torch.__version__)
# Out:
# 8.1.45
# 2.2.2

# %%
#torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3090'

# %% [markdown]
# # 偵察、追蹤並計算人員

# %%
from ultralytics import YOLO

import time
import torch
import cv2
import torch.backends.cudnn as cudnn
from PIL import Image
import colorsys
import numpy as np

# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

results = model("images/motors.jpg", save=True)


class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    probs = result.probs  # Class probabilities for classification outputs
    cls = boxes.cls.tolist()  # Convert tensor to list
    xyxy = boxes.xyxy
    xywh = boxes.xywh  # box with xywh format, (N, 4)
    conf = boxes.conf
    print(cls)
    for class_index in cls:
        class_name = class_names[int(class_index)]
        print("Class:", class_name)
# Out:
# image 1/1 c:\Users\soarb\Desktop\Tracking_and_counting_Using_YOLOv8_and_DeepSORT\images\motors.jpg: 448x640 9 motorcycles, 171.2ms
# Speed: 4.0ms preprocess, 171.2ms inference, 910.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict
# [3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0]
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle
# Class: motorcycle

# %% [markdown]
# # 使用 DeepSORT 套件

# %%
from deep_sort.utils.parser import get_config
from deep_sort.deep_sort import DeepSort
from deep_sort.sort.tracker import Tracker

deep_sort_weights = 'deep_sort/deep/checkpoint/ckpt.t7'
tracker = DeepSort(model_path=deep_sort_weights, max_age=70)

# %%
# Define the video path
video_path = 'images/sample1.mp4'

cap = cv2.VideoCapture(video_path)

# Get the video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_path = 'output.mp4'
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
frames = []

unique_track_ids = set()

# %%
i = 0
counter, fps, elapsed = 0, 0, 0
start_time = time.perf_counter()

while cap.isOpened():
    ret, frame = cap.read()

    if ret:
        
        og_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = og_frame.copy()

        model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

        # results = model(frame, device=0, classes=0, conf=0.8)
        results = model(frame, classes=0, conf=0.8)


        class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

        for result in results:
            boxes = result.boxes  # Boxes object for bbox outputs
            probs = result.probs  # Class probabilities for classification outputs
            cls = boxes.cls.tolist()  # Convert tensor to list
            xyxy = boxes.xyxy
            conf = boxes.conf
            xywh = boxes.xywh  # box with xywh format, (N, 4)
            for class_index in cls:
                class_name = class_names[int(class_index)]
                #print("Class:", class_name)

        pred_cls = np.array(cls)
        conf = conf.detach().cpu().numpy()
        xyxy = xyxy.detach().cpu().numpy()
        bboxes_xywh = xywh
        bboxes_xywh = xywh.cpu().numpy()
        bboxes_xywh = np.array(bboxes_xywh, dtype=float)
        
        tracks = tracker.update(bboxes_xywh, conf, og_frame)
        
        for track in tracker.tracker.tracks:
            track_id = track.track_id
            hits = track.hits
            x1, y1, x2, y2 = track.to_tlbr()  # Get bounding box coordinates in (x1, y1, x2, y2) format
            w = x2 - x1  # Calculate width
            h = y2 - y1  # Calculate height

            # Set color values for red, blue, and green
            red_color = (0, 0, 255)  # (B, G, R)
            blue_color = (255, 0, 0)  # (B, G, R)
            green_color = (0, 255, 0)  # (B, G, R)

            # Determine color based on track_id
            color_id = track_id % 3
            if color_id == 0:
                color = red_color
            elif color_id == 1:
                color = blue_color
            else:
                color = green_color

            cv2.rectangle(og_frame, (int(x1), int(y1)), (int(x1 + w), int(y1 + h)), color, 2)

            text_color = (0, 0, 0)  # Black color for text
            cv2.putText(og_frame, f"{class_name}-{track_id}", (int(x1) + 10, int(y1) - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

            # Add the track_id to the set of unique track IDs
            unique_track_ids.add(track_id)

        # Update the person count based on the number of unique track IDs
        person_count = len(unique_track_ids)

        # Update FPS and place on frame
        current_time = time.perf_counter()
        elapsed = (current_time - start_time)
        counter += 1
        if elapsed > 1:
            fps = counter / elapsed
            counter = 0
            start_time = current_time

        # Draw person count on frame
        cv2.putText(og_frame, f"Person Count: {person_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Append the frame to the list
        frames.append(og_frame)

        # Write the frame to the output video file
        out.write(cv2.cvtColor(og_frame, cv2.COLOR_RGB2BGR))

        #Show the frame
        cv2.imshow("Video", og_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 5 persons, 251.1ms
# Speed: 8.6ms preprocess, 251.1ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 281.0ms
# Speed: 4.0ms preprocess, 281.0ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 275.4ms
# Speed: 4.0ms preprocess, 275.4ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 89.3ms
# Speed: 2.9ms preprocess, 89.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 80.9ms
# Speed: 1.9ms preprocess, 80.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 103.6ms
# Speed: 1.0ms preprocess, 103.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 104.5ms
# Speed: 1.9ms preprocess, 104.5ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 184.3ms
# Speed: 5.1ms preprocess, 184.3ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 195.9ms
# Speed: 4.0ms preprocess, 195.9ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 192.7ms
# Speed: 8.5ms preprocess, 192.7ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 177.7ms
# Speed: 4.0ms preprocess, 177.7ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 179.0ms
# Speed: 2.0ms preprocess, 179.0ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 197.7ms
# Speed: 3.2ms preprocess, 197.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 204.7ms
# Speed: 3.1ms preprocess, 204.7ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 192.6ms
# Speed: 4.0ms preprocess, 192.6ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 189.3ms
# Speed: 5.0ms preprocess, 189.3ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 193.4ms
# Speed: 5.0ms preprocess, 193.4ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 202.5ms
# Speed: 6.0ms preprocess, 202.5ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 232.9ms
# Speed: 4.2ms preprocess, 232.9ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 225.2ms
# Speed: 6.0ms preprocess, 225.2ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 202.9ms
# Speed: 6.0ms preprocess, 202.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 202.5ms
# Speed: 3.9ms preprocess, 202.5ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 196.3ms
# Speed: 7.0ms preprocess, 196.3ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 186.7ms
# Speed: 4.8ms preprocess, 186.7ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 163.4ms
# Speed: 3.6ms preprocess, 163.4ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 170.3ms
# Speed: 3.0ms preprocess, 170.3ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 160.0ms
# Speed: 5.1ms preprocess, 160.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 168.1ms
# Speed: 4.3ms preprocess, 168.1ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 272.3ms
# Speed: 4.0ms preprocess, 272.3ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 196.4ms
# Speed: 5.9ms preprocess, 196.4ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 262.8ms
# Speed: 3.7ms preprocess, 262.8ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 143.4ms
# Speed: 4.0ms preprocess, 143.4ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 209.1ms
# Speed: 7.7ms preprocess, 209.1ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 216.5ms
# Speed: 4.5ms preprocess, 216.5ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 176.6ms
# Speed: 5.7ms preprocess, 176.6ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 225.6ms
# Speed: 5.0ms preprocess, 225.6ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 187.6ms
# Speed: 6.8ms preprocess, 187.6ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 194.2ms
# Speed: 6.5ms preprocess, 194.2ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 211.3ms
# Speed: 5.5ms preprocess, 211.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 210.4ms
# Speed: 6.1ms preprocess, 210.4ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons,